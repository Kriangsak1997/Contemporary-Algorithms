# %%
import numpy as np

# %%
from numpy import genfromtxt
my_data = genfromtxt('/Users/kriangsak1997/Downloads/humsavar.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4abc90007a60> in <module>
#       1 from numpy import genfromtxt
# ----> 2 my_data = genfromtxt('/Users/kriangsak1997/Downloads/humsavar.csv', delimiter=',')
#
# ~/.pyenv/versions/3.7.4/lib/python3.7/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2101             # Raise an exception ?
#    2102             if invalid_raise:
# -> 2103                 raise ValueError(errmsg)
#    2104             # Issue a warning ?
#    2105             else:
#
# ValueError: Some errors were detected !
#     Line #67 (got 9 columns instead of 7)
# ...
